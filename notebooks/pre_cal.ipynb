# %%
import math
import pandas as pd

# %%
"""
current_window = 2026-02-12
window_size = 30d
snapshot_date = 7d


"""





delta_total = -422
delta_active_user = -1035
delta_new_user = -96

# %%
pd.read_parquet('../datasets/c-vit/activity_transaction.parquet')['is_completed']
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995     True
# 9996     True
# 9997     True
# 9998     True
# 9999     True
# Name: is_completed, Length: 10000, dtype: bool
